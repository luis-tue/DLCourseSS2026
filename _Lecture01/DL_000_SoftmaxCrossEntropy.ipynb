# %% [markdown]
# ## Exercise 2
# In the follwing we want to implement the formulas for the softmax layer and the log loss. All this shall be evaluated with the example shown in the graphics below.

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
import numpy as np
# Predicted output vector for sample 1 (Image of the cat)
prediction_x1 = np.array([3.2, 5.1, -1.7])
true_index_x1 = 0
# Predicted output vector for sample 2 (Image of the mouse)
prediction_x2 = np.array([1.3, 4.9, 2.0])
true_index_x2 = 1
# Predicted output vector for sample 2 (Image of the bear)
prediction_x3 = np.array([2.2, 2.5, -3.1])
true_index_x3 = 2

# %% [markdown]
# ### Complete the following function

# %%
import numpy as np

def softmax(scores):
    """
    Calculate the probabilies of all classes from the unnormalized output vector.

    Parameters:
    - scores: np.array, a vector of scores for each class from the classifier.

    Returns:
    - probabilities: np.array.
    """
    pass

# %% [markdown]
# ### Calculate the probability vector
#
# print the outputvector together with the probability vector

# %%
probs1 = softmax(prediction_x1)
print(prediction_x1, "->", probs1)

# %%
probs2 = softmax(prediction_x2)
print(prediction_x2, "->", probs2)

# %%
probs3 = softmax(prediction_x3)
print(prediction_x3, "->", probs2)

# %% [markdown]
# ### Complete the code for the log-loss function

# %%
import numpy as np
import math

def log_loss(probabilities, true_class_index):
    """
    Calculate the log loss (cross-entropy loss) given the probabilities and the true class index.

    Parameters:
    - probabilities: np.array, the probabilities of each class.
    - true_class_index: int, the index of the true class.

    Returns:
    - log_loss: float, the log loss value.
    """
    pass

# %% [markdown]
# ### Evaluate the loss for the cat picture
#
# print the outputvector together with the loss of the sample for the cat picture
