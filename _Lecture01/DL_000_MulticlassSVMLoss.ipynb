# %% [markdown]
# # Exercise 1
# In the follwing we want to implement the formulas for the multiclass svm loss. All this will be evaluated with the example shown in the graphics below.

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
import numpy as np
# Predicted output vector for sample 1 (Image of the cat)
prediction_x1 = np.array([3.2, 5.1, -1.7])
true_index_x1 = 0

np.argmax(prediction_x1)
s
# Out:
# np.int64(1)

# %%
# Predicted output vector for sample 2 (Image of the mouse)
prediction_x2 = np.array([1.3, 4.9, 2.0])
true_index_x2 = 1

np.argmax(prediction_x2)
# Out:
# 1

# %%
# Predicted output vector for sample 3 (Image of the bear)
prediction_x3 = np.array([2.2, 2.5, -3.1])
true_index_x3 = 2

np.argmax(prediction_x3)
# Out:
# 1

# %% [markdown]
# ### Complete the following function

# %%
import numpy as np

def multiclass_svm_loss(scores, true_index):
    """
    Calculate the multiclass SVM loss for a single example.

    Parameters:
    - scores: np.array, a vector of scores for each class from the classifier.
    - true_index: int, the index of the true class for the example.

    Returns:
    - loss: float, the computed multiclass SVM loss for the example.
    """
    pass

# %% [markdown]
# ### Evaluate the loss for each sample
#
# print the outputvector together with the loss of the sample for all three classifications
